# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.set_theme(style="darkgrid")

# %%
df = pd.read_csv("results/results.csv", sep=";")
df = df.drop(columns="Unnamed: 0")

# %%
df
# Out:
#    train_acc  train_loss  test_acc  test_loss  epoch
# 0   0.955333    0.142797  0.988219   0.039648    0.0
# 1   0.983450    0.053412  0.988818   0.038516    1.0
# 2   0.987250    0.041081  0.987320   0.035978    2.0
# 3   0.989167    0.032939  0.990615   0.029700    3.0
# 4   0.990550    0.028926  0.990715   0.027587    4.0
# 5   0.992417    0.022771  0.992412   0.025123    5.0
# 6   0.992467    0.022188  0.994010   0.019118    6.0
# 7   0.994283    0.018044  0.993710   0.020316    7.0
# 8   0.995033    0.016250  0.992812   0.022698    8.0
# 9   0.994917    0.015754  0.993211   0.019929    9.0

# %%
plt.figure(figsize=(8, 4))
sns.lineplot(x='epoch', y='train_acc', data=df, label='train', marker='o')
sns.lineplot(x='epoch', y='test_acc', data=df, label='test', marker='o')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.tight_layout()
plt.savefig("plots/Acc.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.lineplot(x='epoch', y='train_loss', data=df, label='train', marker='o')
sns.lineplot(x='epoch', y='test_loss', data=df, label='test', marker='o')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.tight_layout()
plt.savefig("plots/Loss.png", dpi=300, bbox_inches="tight")
plt.show()
